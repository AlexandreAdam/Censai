# %%
import tensorflow as tf
import numpy as np
import math
from censai import PhysicalModel, RIMSharedResUnet
from censai.definitions import DTYPE
from censai.models import SharedResUnetModel, RayTracer
from censai.data.lenses_tng import decode_train, decode_physical_model_info, preprocess
from censai.utils import nullwriter, rim_residual_plot as residual_plot, plot_to_image
import os, glob, time
from datetime import datetime
from tensorboard.plugins.hparams import api as hp
import random
    
    
RIM_HPARAMS = [
    "adam",
    "steps",
    "kappalog",
    "kappa_normalize",
    "kappa_init",
    "source_init"
]
UNET_MODEL_HPARAMS = [
    "filters",
    "filter_scaling",
    "kernel_size",
    "layers",
    "block_conv_layers",
    "strides",
    "bottleneck_kernel_size",
    "bottleneck_filters",
    "resampling_kernel_size",
    "input_kernel_size",
    "gru_kernel_size",
    "upsampling_interpolation",
    "group_norm",
    "dropout_rate",
    "kernel_l2_amp",
    "bias_l2_amp",
    "kernel_l1_amp",
    "bias_l1_amp",
    "activation",
    "alpha",
    "initializer",
    "gru_architecture"
]

# %%
def main(args):
    files = []
    for dataset in args.datasets:
        files.extend(glob.glob(os.path.join(dataset, "*.tfrecords")))
    np.random.shuffle(files)
    # Read concurrently from multiple records
    files = tf.data.Dataset.from_tensor_slices(files)
    dataset = files.interleave(lambda x: tf.data.TFRecordDataset(x, compression_type=args.compression_type),
                               block_length=args.block_length, num_parallel_calls=tf.data.AUTOTUNE)
    # Read off global parameters from first example in dataset
    for physical_params in dataset.map(decode_physical_model_info):
        break
    # preprocessing
    dataset = dataset.map(decode_train).map(preprocess)
    if args.cache_file is not None:
        dataset = dataset.cache(args.cache_file)
#     train_dataset = dataset.shuffle(buffer_size=args.buffer_size).take(math.floor(args.train_split * args.total_items))\
#         .batch(args.batch_size).prefetch(tf.data.experimental.AUTOTUNE)
    train_dataset = dataset.take(math.floor(args.train_split * args.total_items))\
        .batch(args.batch_size).prefetch(tf.data.experimental.AUTOTUNE)
    val_dataset = dataset.skip(math.floor(args.train_split * args.total_items))\
        .take(math.ceil((1 - args.train_split) * args.total_items)).batch(args.batch_size).prefetch(tf.data.experimental.AUTOTUNE)
    # train_dataset = STRATEGY.experimental_distribute_dataset(train_dataset)
    # val_dataset = STRATEGY.experimental_distribute_dataset(val_dataset)
    if args.raytracer is not None:
        with open(os.path.join(args.raytracer, "ray_tracer_hparams.json"), "r") as f:
            raytracer_hparams = json.load(f)
    # with STRATEGY.scope():  # Replicate ops accross gpus
    if args.raytracer is not None:
        raytracer = RayTracer(**raytracer_hparams)
        # load last checkpoint in the checkpoint directory
        checkpoint = tf.train.Checkpoint(net=raytracer)
        manager = tf.train.CheckpointManager(checkpoint, directory=args.raytracer, max_to_keep=3)
        checkpoint.restore(manager.latest_checkpoint).expect_partial()
    else:
        raytracer = None
    phys = PhysicalModel(
        pixels=physical_params["pixels"].numpy(),
        kappa_pixels=physical_params["kappa pixels"].numpy(),
        src_pixels=physical_params["src pixels"].numpy(),
        image_fov=physical_params["image fov"].numpy(),
        kappa_fov=physical_params["kappa fov"].numpy(),
        src_fov=physical_params["source fov"].numpy(),
        method=args.forward_method,
        noise_rms=physical_params["noise rms"].numpy(),
        raytracer=raytracer,
        psf_sigma=physical_params["psf sigma"].numpy()
    )

    unet = SharedResUnetModel(
        filters=args.filters,
        filter_scaling=args.filter_scaling,
        kernel_size=args.kernel_size,
        layers=args.layers,
        block_conv_layers=args.block_conv_layers,
        strides=args.strides,
        bottleneck_kernel_size=args.bottleneck_kernel_size,
        bottleneck_filters=args.bottleneck_filters,
        resampling_kernel_size=args.resampling_kernel_size,
        input_kernel_size=args.input_kernel_size,
        gru_kernel_size=args.gru_kernel_size,
        upsampling_interpolation=args.upsampling_interpolation,
        kernel_l2_amp=args.kernel_l2_amp,
        bias_l2_amp=args.bias_l2_amp,
        kernel_l1_amp=args.kernel_l1_amp,
        bias_l1_amp=args.bias_l1_amp,
        activation=args.activation,
        alpha=args.alpha,
        initializer=args.initializer,
        group_norm=args.group_norm,
        dropout_rate=args.dropout_rate,
        gru_architecture=args.gru_architecture
    )
    rim = RIMSharedResUnet(
        physical_model=phys,
        unet=unet,
        steps=args.steps,
        adam=args.adam,
        kappalog=args.kappalog,
        source_link=args.source_link,
        kappa_normalize=args.kappa_normalize,
        kappa_init=args.kappa_init,
        source_init=args.source_init
    )
    learning_rate_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=args.initial_learning_rate,
        decay_rate=args.decay_rate,
        decay_steps=args.decay_steps,
        staircase=args.staircase
    )
    optim = tf.keras.optimizers.deserialize(
        {
            "class_name": args.optimizer,
            'config': {"learning_rate": learning_rate_schedule}
        }
    )
    # weights for time steps in the loss function
    if args.time_weights == "uniform":
        wt = tf.ones(shape=(args.steps), dtype=DTYPE) / args.steps
    elif args.time_weights == "linear":
        wt = 2 * (tf.range(args.steps, dtype=DTYPE) + 1) / args.steps / (args.steps + 1)
    elif args.time_weights == "quadratic":
        wt = 6 * (tf.range(args.steps, dtype=DTYPE) + 1)**2 / args.steps / (args.steps + 1) / (2 * args.steps + 1)
    else:
        raise ValueError("time_weights must be in ['uniform', 'linear', 'quadratic']")
#     wt = (tf.range(args.steps, dtype=DTYPE) + 1)**4
#     wt /= tf.reduce_sum(wt)
    wt = wt[..., tf.newaxis]  # [steps, batch]
    # ==== Take care of where to write logs and stuff =================================================================
    if args.model_id.lower() != "none":
        logname = args.model_id + "_" + args.logname if args.logname is not None else args.model_id
        model_id = args.model_id
    elif args.logname is not None:
        logname = args.logname
        model_id = logname
    else:
        logname = args.logname_prefixe + "_" + datetime.now().strftime("%y-%m-%d_%H-%M-%S")
        model_id = logname
    if args.logdir.lower() != "none":
        logdir = os.path.join(args.logdir, logname)
        if not os.path.isdir(logdir):
            os.mkdir(logdir)
        writer = tf.summary.create_file_writer(logdir)
    else:
        writer = nullwriter()
    # ===== Make sure directory and checkpoint manager are created to save model ===================================
    if args.model_dir.lower() != "none":
        checkpoints_dir = os.path.join(args.model_dir, logname)
        old_checkpoints_dir = os.path.join(args.model_dir, model_id)  # in case they differ we load model from a different directory
        if not os.path.isdir(checkpoints_dir):
            os.mkdir(checkpoints_dir)
            with open(os.path.join(checkpoints_dir, "script_params.json"), "w") as f:
                json.dump(vars(args), f, indent=4)
            with open(os.path.join(checkpoints_dir, "unet_hparams.json"), "w") as f:
                hparams_dict = {key: vars(args)[key] for key in UNET_MODEL_HPARAMS}
                json.dump(hparams_dict, f, indent=4)
            with open(os.path.join(checkpoints_dir, "rim_hparams.json"), "w") as f:
                hparams_dict = {key: vars(args)[key] for key in RIM_HPARAMS}
                json.dump(hparams_dict, f, indent=4)
        ckpt = tf.train.Checkpoint(step=tf.Variable(1), optimizer=optim, net=rim.unet)
        checkpoint_manager = tf.train.CheckpointManager(ckpt, old_checkpoints_dir, max_to_keep=args.max_to_keep)
        save_checkpoint = True
        # ======= Load model if model_id is provided ===============================================================
        if args.model_id.lower() != "none":
            checkpoint_manager.checkpoint.restore(checkpoint_manager.latest_checkpoint)
        if old_checkpoints_dir != checkpoints_dir:  # save progress in another directory.
            checkpoint_manager = tf.train.CheckpointManager(ckpt, checkpoints_dir, max_to_keep=args.max_to_keep)
    else:
        save_checkpoint = False
    # =================================================================================================================

    def train_step(X, source, kappa):
        with tf.GradientTape() as tape:
            tape.watch(rim.unet.trainable_variables)
            if args.unroll_time_steps:
                source_series, kappa_series, chi_squared = rim.call_function(X)
            else:
                source_series, kappa_series, chi_squared = rim.call(X, outer_tape=tape)
            # mean over image residuals
            source_cost = tf.reduce_mean(tf.square(source_series - rim.source_inverse_link(source)), axis=(2, 3, 4))
            kappa_cost = tf.reduce_mean(tf.square(kappa_series - rim.kappa_inverse_link(kappa)), axis=(2, 3, 4))
            # weighted mean over time steps
            source_cost = tf.reduce_sum(wt * source_cost, axis=0)
            kappa_cost = tf.reduce_sum(wt * kappa_cost, axis=0)
            # final cost is mean over global batch size
            cost = tf.reduce_sum(kappa_cost + source_cost) / args.batch_size
        gradient = tape.gradient(cost, rim.unet.trainable_variables)
        if args.clipping:
            gradient = [tf.clip_by_value(grad, -10, 10) for grad in gradient]
        optim.apply_gradients(zip(gradient, rim.unet.trainable_variables))
        chi_squared = tf.reduce_sum(chi_squared[-1]) / args.batch_size # take chi squared of converged prediction
        source_cost = tf.reduce_sum(source_cost) / args.batch_size
        kappa_cost = tf.reduce_sum(kappa_cost) / args.batch_size
        return cost, chi_squared, source_cost, kappa_cost

    # @tf.function
    # def distributed_train_step(dist_inputs):
    #     per_replica_losses, per_replica_chi_squared, per_replica_source_cost, per_replica_kappa_cost = STRATEGY.run(train_step, args=(dist_inputs,))
    #     # Replica losses are aggregated by summing them
    #     global_loss = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_losses, axis=None)
    #     global_chi_squared = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_chi_squared, axis=None)
    #     global_source_cost = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_source_cost, axis=None)
    #     global_kappa_cost = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_kappa_cost, axis=None)
    #     return global_loss, global_chi_squared, global_source_cost, global_kappa_cost

    def test_step(X, source, kappa):
        source_series, kappa_series, chi_squared = rim.call(X)
        # mean over image residuals
        source_cost = tf.reduce_mean(tf.square(source_series - rim.source_inverse_link(source)), axis=(2, 3, 4))
        kappa_cost = tf.reduce_mean(tf.square(kappa_series - rim.kappa_inverse_link(kappa)), axis=(2, 3, 4))
        # weighted mean over time steps
        source_cost = tf.reduce_sum(wt * source_cost, axis=0)
        kappa_cost = tf.reduce_sum(wt * kappa_cost, axis=0)
        # final cost is mean over global batch size
        cost = tf.reduce_sum(kappa_cost + source_cost) / args.batch_size
        chi_squared = tf.reduce_sum(chi_squared[-1]) / args.batch_size
        source_cost = tf.reduce_sum(source_cost) / args.batch_size
        kappa_cost = tf.reduce_sum(kappa_cost) / args.batch_size
        return cost, chi_squared, source_cost, kappa_cost

    # @tf.function
    # def distributed_test_step(dist_inputs):
    #     per_replica_losses, per_replica_chi_squared, per_replica_source_cost, per_replica_kappa_cost = STRATEGY.run(test_step, args=(dist_inputs,))
    #     # Replica losses are aggregated by summing them
    #     global_loss = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_losses, axis=None)
    #     global_chi_squared = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_chi_squared, axis=None)
    #     global_source_cost = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_source_cost, axis=None)
    #     global_kappa_cost = STRATEGY.reduce(tf.distribute.ReduceOp.SUM, per_replica_kappa_cost, axis=None)
    #     return global_loss, global_chi_squared, global_source_cost, global_kappa_cost

    # ====== Training loop ============================================================================================
    epoch_loss = tf.metrics.Mean()
    time_per_step = tf.metrics.Mean()
    val_loss = tf.metrics.Mean()
    epoch_chi_squared = tf.metrics.Mean()
    epoch_source_loss = tf.metrics.Mean()
    epoch_kappa_loss = tf.metrics.Mean()
    val_chi_squared = tf.metrics.Mean()
    val_source_loss = tf.metrics.Mean()
    val_kappa_loss = tf.metrics.Mean()
    history = {  # recorded at the end of an epoch only
        "train_cost": [],
        "train_chi_squared": [],
        "train_source_cost": [],
        "train_kappa_cost": [],
        "val_cost": [],
        "val_chi_squared": [],
        "val_source_cost": [],
        "val_kappa_cost": [],
        "learning_rate": [],
        "time_per_step": [],
        "step": [],
        "wall_time": []
    }
    best_loss = np.inf
    patience = args.patience
    step = 0
    global_start = time.time()
    estimated_time_for_epoch = 0
    out_of_time = False
    lastest_checkpoint = 1
    for epoch in range(args.epochs):
        if (time.time() - global_start) > args.max_time*3600 - estimated_time_for_epoch:
            break
        epoch_start = time.time()
        epoch_loss.reset_states()
        epoch_chi_squared.reset_states()
        epoch_source_loss.reset_states()
        epoch_kappa_loss.reset_states()
        time_per_step.reset_states()
        with writer.as_default():
            for batch, (X, source, kappa) in enumerate(train_dataset):
                start = time.time()
                cost, chi_squared, source_cost, kappa_cost = train_step(X, source, kappa)
        # ========== Summary and logs ==================================================================================
                _time = time.time() - start
                time_per_step.update_state([_time])
                epoch_loss.update_state([cost])
                epoch_chi_squared.update_state([chi_squared])
                epoch_source_loss.update_state([source_cost])
                epoch_kappa_loss.update_state([kappa_cost])
                step += 1
#             # last batch we make a summary of residuals
#             if args.n_residuals > 0:
#                 source_pred, kappa_pred, chi_squared = rim.predict(X)
#                 lens_pred = phys.forward(source_pred[-1], kappa_pred[-1])
#                 lam = phys.lagrange_multiplier(y_true=X, y_pred=lens_pred)
#             for res_idx in range(min(args.n_residuals, args.batch_size)):
#                 try:
#                     tf.summary.image(f"Residuals {res_idx}",
#                                      plot_to_image(
#                                          residual_plot(
#                                              lam[res_idx]*X[res_idx],
#                                              source[res_idx],
#                                              kappa[res_idx],
#                                              lens_pred[res_idx],
#                                              source_pred[-1][res_idx],
#                                              kappa_pred[-1][res_idx],
#                                              chi_squared[-1][res_idx]
#                                          )), step=step)
#                 except ValueError:
#                     continue

#             # ========== Validation set ===================
#             val_loss.reset_states()
#             val_chi_squared.reset_states()
#             val_source_loss.reset_states()
#             val_kappa_loss.reset_states()
#             for X, source, kappa in val_dataset:
#                 cost, chi_squared, source_cost, kappa_cost = test_step(X, source, kappa)
#                 val_loss.update_state([cost])
#                 val_chi_squared.update_state([chi_squared])
#                 val_source_loss.update_state([source_cost])
#                 val_kappa_loss.update_state([kappa_cost])

#             if args.n_residuals > 0 and math.ceil((1 - args.train_split) * args.total_items) > 0:  # validation set not empty set not empty
#                 source_pred, kappa_pred, chi_squared = rim.predict(X)
#                 lens_pred = phys.forward(source_pred[-1], kappa_pred[-1])
#                 lam = phys.lagrange_multiplier(y_true=X, y_pred=lens_pred)
#             for res_idx in range(min(args.n_residuals, args.batch_size, math.ceil((1 - args.train_split) * args.total_items))):
#                 try:
#                     tf.summary.image(f"Val Residuals {res_idx}",
#                                      plot_to_image(
#                                          residual_plot(
#                                              lam[res_idx]*X[res_idx],  # rescale intensity like it is done in the likelihood
#                                              source[res_idx],
#                                              kappa[res_idx],
#                                              lens_pred[res_idx],
#                                              source_pred[-1][res_idx],
#                                              kappa_pred[-1][res_idx],
#                                              chi_squared[-1][res_idx]
#                                          )), step=step)
#                 except ValueError:
#                     continue
            val_cost = val_loss.result().numpy()
            train_cost = epoch_loss.result().numpy()
            val_chi_sq = val_chi_squared.result().numpy()
            train_chi_sq = epoch_chi_squared.result().numpy()
            val_kappa_cost = val_kappa_loss.result().numpy()
            train_kappa_cost = epoch_kappa_loss.result().numpy()
            val_source_cost = val_source_loss.result().numpy()
            train_source_cost = epoch_source_loss.result().numpy()
#             tf.summary.scalar("Time per step", time_per_step.result(), step=step)
#             tf.summary.scalar("Chi Squared", train_chi_sq, step=step)
#             tf.summary.scalar("Kappa cost", train_kappa_cost, step=step)
#             tf.summary.scalar("Val Kappa cost", val_kappa_cost, step=step)
#             tf.summary.scalar("Source cost", train_source_cost, step=step)
#             tf.summary.scalar("Val Source cost", val_source_cost, step=step)
#             tf.summary.scalar("MSE", train_cost, step=step)
#             tf.summary.scalar("Val MSE", val_cost, step=step)
#             tf.summary.scalar("Learning Rate", optim.lr(step), step=step)
#             tf.summary.scalar("Val Chi Squared", val_chi_sq, step=step)
        print(f"epoch {epoch} | train loss {train_cost:.3e} | val loss {val_cost:.3e} "
              f"| lr {optim.lr(step).numpy():.2e} | time per step {time_per_step.result().numpy():.2e} s"
              f"| kappa cost {train_kappa_cost:.2e} | source cost {train_source_cost:.2e} | chi sq {train_chi_sq:.2e}")
        history["train_cost"].append(train_cost)
#         history["val_cost"].append(val_cost)
        history["learning_rate"].append(optim.lr(step).numpy())
        history["train_chi_squared"].append(train_chi_sq)
#         history["val_chi_squared"].append(val_chi_sq)
        history["time_per_step"].append(time_per_step.result().numpy())
        history["train_kappa_cost"].append(train_kappa_cost)
        history["train_source_cost"].append(train_source_cost)
#         history["val_kappa_cost"].append(val_kappa_cost)
#         history["val_source_cost"].append(val_source_cost)
        history["step"].append(step)
        history["wall_time"].append(time.time() - global_start)

        cost = train_cost if args.track_train else val_cost
        if np.isnan(cost):
            print("Training broke the Universe")
            break
        if cost < (1 - args.tolerance) * best_loss:
            best_loss = cost
            patience = args.patience
        else:
            patience -= 1
        if (time.time() - global_start) > args.max_time * 3600:
            out_of_time = True
        if save_checkpoint:
            checkpoint_manager.checkpoint.step.assign_add(1) # a bit of a hack
            if epoch % args.checkpoints == 0 or patience == 0 or epoch == args.epochs - 1 or out_of_time:
                with open(os.path.join(checkpoints_dir, "score_sheet.txt"), mode="a") as f:
                    np.savetxt(f, np.array([[lastest_checkpoint, cost]]))
                lastest_checkpoint += 1
                checkpoint_manager.save()
                print("Saved checkpoint for step {}: {}".format(int(checkpoint_manager.checkpoint.step), checkpoint_manager.latest_checkpoint))
        if patience == 0:
            print("Reached patience")
            break
        if out_of_time:
            break
        if epoch > 0:  # First epoch is always very slow and not a good estimate of an epoch time.
            estimated_time_for_epoch = time.time() - epoch_start
    print(f"Finished training after {(time.time() - global_start)/3600:.3f} hours.")
    return rim, phys, train_dataset, val_dataset

# %%
from argparse import ArgumentParser
import json
parser = ArgumentParser()

parser.add_argument("--model_id",               default="None",                 help="Start from this model id checkpoint. None means start from scratch")
parser.add_argument("--datasets",               required=True,  nargs="+",      help="Path to directories that contains tfrecords of dataset. Can be multiple inputs (space separated)")
parser.add_argument("--compression_type",       default=None,                   help="Compression type used to write data. Default assumes no compression.")

# RIM hyperparameters
parser.add_argument("--steps",              default=16,     type=int,       help="Number of time steps of RIM")
parser.add_argument("--adam",               action="store_true",            help="ADAM update for the log-likelihood gradient.")
parser.add_argument("--kappalog",           action="store_true")
parser.add_argument("--kappa_normalize",    action="store_true")
parser.add_argument("--source_link",        default="identity",             help="One of 'exp', 'source', 'relu' or 'identity' (default).")
parser.add_argument("--kappa_init",         default=1e-1,   type=float,     help="Initial value of kappa for RIM")
parser.add_argument("--source_init",        default=1e-3,   type=float,     help="Initial value of source for RIM")

# Shared Unet params
parser.add_argument("--filters",                                    default=32,     type=int)
parser.add_argument("--filter_scaling",                             default=1,      type=float)
parser.add_argument("--kernel_size",                                default=3,      type=int)
parser.add_argument("--layers",                                     default=2,      type=int)
parser.add_argument("--block_conv_layers",                          default=2,      type=int)
parser.add_argument("--strides",                                    default=2,      type=int)
parser.add_argument("--bottleneck_kernel_size",                     default=None,   type=int)
parser.add_argument("--bottleneck_filters",                         default=None,   type=int)
parser.add_argument("--resampling_kernel_size",                     default=None,   type=int)
parser.add_argument("--input_kernel_size",                          default=11,     type=int)
parser.add_argument("--gru_kernel_size",                            default=None,   type=int)
parser.add_argument("--upsampling_interpolation",                   action="store_true")
parser.add_argument("--group_norm",                                 action="store_true")
parser.add_argument("--dropout_rate",                               default=None,   type=float)
parser.add_argument("--kernel_l2_amp",                              default=0,      type=float)
parser.add_argument("--bias_l2_amp",                                default=0,      type=float)
parser.add_argument("--kernel_l1_amp",                              default=0,      type=float)
parser.add_argument("--bias_l1_amp",                                default=0,      type=float)
parser.add_argument("--activation",                                 default="leaky_relu")
parser.add_argument("--alpha",                                      default=0.1,    type=float)
parser.add_argument("--initializer",                                default="glorot_normal")
parser.add_argument("--gru_architecture",                           default="concat",   help="'concat': architecture of Laurence. 'plus': original RNN architecture")


# Physical model hyperparameter
parser.add_argument("--forward_method",         default="conv2d",               help="One of ['conv2d', 'fft', 'unet']. If the option 'unet' is chosen, the parameter "
                                                                                     "'--raytracer' must be provided and point to model checkpoint directory.")
parser.add_argument("--raytracer",              default=None,                   help="Path to raytracer checkpoint dir if method 'unet' is used.")

# Training set params
parser.add_argument("-b", "--batch_size",       default=1,      type=int,       help="Number of images in a batch. ")
parser.add_argument("--train_split",            default=0.8,    type=float,     help="Fraction of the training set.")
parser.add_argument("--total_items",            required=True,  type=int,       help="Total images in an epoch.")
# ... for tfrecord dataset
parser.add_argument("--cache_file",             default=None,                   help="Path to cache file, useful when training on server. Use ${SLURM_TMPDIR}/cache")
parser.add_argument("--block_length",           default=1,      type=int,       help="Number of example to read from each files at a given moment.")
parser.add_argument("--buffer_size",            default=1000,   type=int,       help="Buffer size for shuffling at each epoch.")

# Optimization params
parser.add_argument("-e", "--epochs",           default=10,     type=int,       help="Number of epochs for training.")
parser.add_argument("--optimizer",              default="Adam",                 help="Class name of the optimizer (e.g. 'Adam' or 'Adamax')")
parser.add_argument("--initial_learning_rate",  default=1e-3,   type=float,     help="Initial learning rate.")
parser.add_argument("--decay_rate",             default=1.,     type=float,     help="Exponential decay rate of learning rate (1=no decay).")
parser.add_argument("--decay_steps",            default=1000,   type=int,       help="Decay steps of exponential decay of the learning rate.")
parser.add_argument("--staircase",              action="store_true",            help="Learning rate schedule only change after decay steps if enabled.")
parser.add_argument("--clipping",               action="store_true",            help="Clip backprop gradients between -10 and 10.")
parser.add_argument("--patience",               default=np.inf, type=int,       help="Number of step at which training is stopped if no improvement is recorder.")
parser.add_argument("--tolerance",              default=0,      type=float,     help="Current score <= (1 - tolerance) * best score => reset patience, else reduce patience.")
parser.add_argument("--track_train",            action="store_true",            help="Track training metric instead of validation metric, in case we want to overfit")
parser.add_argument("--max_time",               default=np.inf, type=float,     help="Time allowed for the training, in hours.")
parser.add_argument("--time_weights",           default="uniform",              help="uniform: w_t=1 for all t, linear: w_t~t, quadratic: w_t~t^2")
parser.add_argument("--unroll_time_steps",      action="store_true",            help="Unroll time steps of RIM in GPU usinf tf.function")


# logs
parser.add_argument("--logdir",                  default="None",                help="Path of logs directory. Default if None, no logs recorded.")
parser.add_argument("--logname",                 default=None,                  help="Overwrite name of the log with this argument")
parser.add_argument("--logname_prefixe",         default="RIMUnet512",          help="If name of the log is not provided, this prefix is prepended to the date")
parser.add_argument("--model_dir",               default="None",                help="Path to the directory where to save models checkpoints.")
parser.add_argument("--checkpoints",             default=10,    type=int,       help="Save a checkpoint of the models each {%} iteration.")
parser.add_argument("--max_to_keep",             default=3,     type=int,       help="Max model checkpoint to keep.")
parser.add_argument("--n_residuals",             default=1,     type=int,       help="Number of residual plots to save. Add overhead at the end of an epoch only.")

# Reproducibility params
parser.add_argument("--seed",                   default=None,   type=int,       help="Random seed for numpy and tensorflow.")
parser.add_argument("--json_override",          default=None,    nargs="+",     help="A json filepath that will override every command line parameters. "
                                                                             "Useful for reproducibility")
# Out:
# _StoreAction(option_strings=['--json_override'], dest='json_override', nargs='+', const=None, default=None, type=None, choices=None, help='A json filepath that will override every command line parameters. Useful for reproducibility', metavar=None)

# %%
import sys
sys.argv = ['']
args = parser.parse_args(
  f"--datasets {os.getenv('CENSAI_PATH')}/data/lenses512_hk128_TNG100_10k_verydiffuse "\
  f"--forward_method=fft "\
#   f"--forward_method=unet "\
#   f"--raytracer={os.getenv('CENSAI_PATH')}/models/RT128_512_grid4_010_FS2.0_K3_F16_42_lr0.0001_ds50000_211006132142 "\
  f"--compression_type=GZIP "\
  f"--optimizer=ADAM "\
  f"--epochs=1000 "\
  f"--max_time=1 "\
  f"--initial_learning_rate=1e-2 "\
  f"--decay_rate=0.5 "\
  f"--decay_steps=200 "\
  f"--staircase "\
  f"--clipping "\
  f"--patience=500 "\
  f"--tolerance=0.01 "\
  f"--batch_size=1 "\
  f"--train_split=1 "\
  f"--total_items=1 "\
  f"--block_length=1 "\
  f"--buffer_size=100 "\
  f"--steps=5 "\
  f"--time_weights=quadratic "\
  f"--adam "\
  f"--kappalog "\
  f"--source_link=lrelu4p "\
  f"--filters=16 "\
  f"--filter_scaling=2 "\
  f"--kernel_size=3 "\
  f"--input_kernel_size=1 "\
  f"--layers=4 "\
  f"--block_conv_layers=1 "\
  "--kappa_init=1e-1 "\
  "--source_init=1e-1 "\
  f"--resampling_kernel_size=1 "\
  f"--group_norm "\
  f"--activation=relu "\
  f"--cache_file={os.getenv('SLURM_TMPDIR')}/cache "\
  f"--logdir={os.getenv('HOME')}/scratch/Censai/logs "\
  f"--logname_prefixe=RIMSU512_k128_hTNG_interactive "\
  f"--track_train "\
  f"--model_dir={os.getenv('HOME')}/scratch/Censai/models "\
  f"--checkpoints=5 "\
  f"--max_to_keep=3 "\
  f"--seed=42 "\
  f"--n_residuals=0 "\
   "--unroll_time_steps "\
   "--track_train".split(" ")
#   f"--json_override {os.getenv('CENSAI_PATH')}/models/{model_id}/unet_hparams.json {os.getenv('CENSAI_PATH')}/models/{model_id}/rim_hparams.json".split()
)
if args.json_override is not None:
    if isinstance(args.json_override, list):
        files = args.json_override
    else:
        files = [args.json_override,]
    for file in files:
        with open(file, "r") as f:
            json_override = json.load(f)
        args_dict = vars(args)
        args_dict.update(json_override)
cache_files = glob.glob(f"{os.getenv('SLURM_TMPDIR')}/cache*")
for cache in cache_files:
    os.remove(cache)
rim, phys, train_dataset, val_dataset = main(args)
# Out:
# epoch 0 | train loss 4.706e+01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 4.78e+01 s| kappa cost 2.47e+01 | source cost 2.23e+01 | chi sq 3.29e+02
# Saved checkpoint for step 2: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-1
# epoch 1 | train loss 2.676e+02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.71e-01 s| kappa cost 2.05e+02 | source cost 6.31e+01 | chi sq 3.29e+02
# epoch 2 | train loss 4.348e+01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.47e-01 s| kappa cost 2.78e+01 | source cost 1.57e+01 | chi sq 3.29e+02
# epoch 3 | train loss 1.680e+01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.50e-01 s| kappa cost 5.69e+00 | source cost 1.11e+01 | chi sq 3.29e+02
# epoch 4 | train loss 8.953e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.51e-01 s| kappa cost 6.93e+00 | source cost 2.02e+00 | chi sq 2.80e+03
# epoch 5 | train loss 1.038e+01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.37e-01 s| kappa cost 3.17e+00 | source cost 7.20e+00 | chi sq 1.51e+05
# Saved checkpoint for step 7: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-2
# epoch 6 | train loss 1.718e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.41e-01 s| kappa cost 9.73e-01 | source cost 7.45e-01 | chi sq 9.15e+03
# epoch 7 | train loss 1.502e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.47e-01 s| kappa cost 1.23e+00 | source cost 2.77e-01 | chi sq 3.29e+02
# epoch 8 | train loss 3.246e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.48e-01 s| kappa cost 8.69e-01 | source cost 2.38e+00 | chi sq 4.47e+02
# epoch 9 | train loss 2.358e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.46e-01 s| kappa cost 8.27e-01 | source cost 1.53e+00 | chi sq 3.30e+02
# epoch 10 | train loss 1.933e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.56e-01 s| kappa cost 6.01e-01 | source cost 1.33e+00 | chi sq 3.77e+02
# Saved checkpoint for step 12: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-3
# epoch 11 | train loss 1.605e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.68e-01 s| kappa cost 3.43e-01 | source cost 1.26e+00 | chi sq 4.36e+03
# epoch 12 | train loss 1.331e+00 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.39e-01 s| kappa cost 4.93e-01 | source cost 8.38e-01 | chi sq 2.22e+03
# epoch 13 | train loss 9.834e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.56e-01 s| kappa cost 3.97e-01 | source cost 5.86e-01 | chi sq 1.59e+03
# epoch 14 | train loss 8.829e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.46e-01 s| kappa cost 5.88e-01 | source cost 2.95e-01 | chi sq 3.35e+02
# epoch 15 | train loss 8.889e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 1.65e+00 s| kappa cost 6.59e-01 | source cost 2.30e-01 | chi sq 3.34e+02
# Saved checkpoint for step 17: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-4
# epoch 16 | train loss 8.892e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.54e-01 s| kappa cost 6.49e-01 | source cost 2.40e-01 | chi sq 3.34e+02
# epoch 17 | train loss 7.705e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.63e-01 s| kappa cost 5.15e-01 | source cost 2.55e-01 | chi sq 3.38e+02
# epoch 18 | train loss 6.357e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.51e-01 s| kappa cost 4.13e-01 | source cost 2.23e-01 | chi sq 2.88e+02
# epoch 19 | train loss 4.441e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.51e-01 s| kappa cost 2.72e-01 | source cost 1.72e-01 | chi sq 4.11e+02
# epoch 20 | train loss 3.614e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.69e-01 s| kappa cost 2.08e-01 | source cost 1.53e-01 | chi sq 1.08e+03
# Saved checkpoint for step 22: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-5
# epoch 21 | train loss 3.424e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.57e-01 s| kappa cost 2.00e-01 | source cost 1.43e-01 | chi sq 1.34e+03
# epoch 22 | train loss 2.464e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.51e-01 s| kappa cost 1.50e-01 | source cost 9.61e-02 | chi sq 3.81e+02
# epoch 23 | train loss 3.490e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.45e-01 s| kappa cost 2.29e-01 | source cost 1.20e-01 | chi sq 2.82e+02
# epoch 24 | train loss 2.489e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.59e-01 s| kappa cost 1.59e-01 | source cost 8.97e-02 | chi sq 4.19e+02
# epoch 25 | train loss 2.566e-01 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.61e-01 s| kappa cost 1.71e-01 | source cost 8.60e-02 | chi sq 5.07e+02
# Saved checkpoint for step 27: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt
-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.60e-01 s| kappa cost 3.91e-02 | source cost 8.88e-03 | chi sq 2.61e+02
# epoch 98 | train loss 4.867e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.51e-01 s| kappa cost 3.99e-02 | source cost 8.73e-03 | chi sq 2.59e+02
# epoch 99 | train loss 4.839e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.34e-01 s| kappa cost 3.95e-02 | source cost 8.92e-03 | chi sq 2.72e+02
# epoch 100 | train loss 4.832e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.43e-01 s| kappa cost 3.92e-02 | source cost 9.15e-03 | chi sq 2.54e+02
# Saved checkpoint for step 102: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-21
# epoch 101 | train loss 4.786e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.55e-01 s| kappa cost 3.93e-02 | source cost 8.57e-03 | chi sq 2.52e+02
# epoch 102 | train loss 4.830e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.47e-01 s| kappa cost 3.99e-02 | source cost 8.38e-03 | chi sq 2.33e+02
# epoch 103 | train loss 4.691e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.54e-01 s| kappa cost 3.86e-02 | source cost 8.27e-03 | chi sq 2.36e+02
# epoch 104 | train loss 4.859e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.58e-01 s| kappa cost 4.00e-02 | source cost 8.64e-03 | chi sq 2.62e+02
# epoch 105 | train loss 4.746e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 1.57e+00 s| kappa cost 3.89e-02 | source cost 8.53e-03 | chi sq 2.58e+02
# Saved checkpoint for step 107: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-22
# epoch 106 | train loss 4.481e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.48e-01 s| kappa cost 3.68e-02 | source cost 8.02e-03 | chi sq 2.37e+02
# epoch 107 | train loss 4.630e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.46e-01 s| kappa cost 3.76e-02 | source cost 8.67e-03 | chi sq 2.46e+02
# epoch 108 | train loss 4.406e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.52e-01 s| kappa cost 3.59e-02 | source cost 8.19e-03 | chi sq 2.32e+02
# epoch 109 | train loss 4.366e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.45e-01 s| kappa cost 3.55e-02 | source cost 8.13e-03 | chi sq 2.39e+02
# epoch 110 | train loss 4.563e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.40e-01 s| kappa cost 3.73e-02 | source cost 8.35e-03 | chi sq 2.45e+02
# Saved checkpoint for step 112: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-23
# epoch 111 | train loss 4.367e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.72e-01 s| kappa cost 3.59e-02 | source cost 7.79e-03 | chi sq 2.32e+02
# epoch 112 | train loss 4.324e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.58e-01 s| kappa cost 3.56e-02 | source cost 7.66e-03 | chi sq 2.34e+02
# epoch 113 | train loss 4.488e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.49e-01 s| kappa cost 3.68e-02 | source cost 8.05e-03 | chi sq 2.27e+02
# epoch 114 | train loss 4.254e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.51e-01 s| kappa cost 3.49e-02 | source cost 7.65e-03 | chi sq 1.93e+02
# epoch 115 | train loss 4.247e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.57e-01 s| kappa cost 3.49e-02 | source cost 7.59e-03 | chi sq 2.18e+02
# Saved checkpoint for step 117: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-24
# epoch 116 | train loss 4.332e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.56e-01 s| kappa cost 3.58e-02 | source cost 7.47e-03 | chi sq 2.30e+02
# epoch 117 | train loss 4.870e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.57e-01 s| kappa cost 3.98e-02 | source cost 8.89e-03 | chi sq 1.97e+02
# epoch 118 | train loss 4.320e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.56e-01 s| kappa cost 3.55e-02 | source cost 7.66e-03 | chi sq 3.02e+02
# epoch 119 | train loss 5.172e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.50e-01 s| kappa cost 4.27e-02 | source cost 8.99e-03 | chi sq 2.47e+02
# epoch 120 | train loss 6.921e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.71e-01 s| kappa cost 5.49e-02 | source cost 1.43e-02 | chi sq 2.73e+02
# Saved checkpoint for step 122: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-25
# epoch 121 | train loss 5.065e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5
/home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-30
# epoch 146 | train loss 4.026e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.63e-01 s| kappa cost 3.36e-02 | source cost 6.66e-03 | chi sq 2.90e+02
# epoch 147 | train loss 4.137e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.52e-01 s| kappa cost 3.48e-02 | source cost 6.61e-03 | chi sq 2.86e+02
# epoch 148 | train loss 4.046e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.45e-01 s| kappa cost 3.42e-02 | source cost 6.26e-03 | chi sq 2.56e+02
# epoch 149 | train loss 4.840e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.53e-01 s| kappa cost 4.16e-02 | source cost 6.76e-03 | chi sq 2.46e+02
# epoch 150 | train loss 4.684e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.56e-01 s| kappa cost 4.05e-02 | source cost 6.36e-03 | chi sq 2.57e+02
# Saved checkpoint for step 152: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-31
# epoch 151 | train loss 4.497e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.49e-01 s| kappa cost 3.86e-02 | source cost 6.34e-03 | chi sq 2.74e+02
# epoch 152 | train loss 4.463e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.68e-01 s| kappa cost 3.81e-02 | source cost 6.53e-03 | chi sq 2.81e+02
# epoch 153 | train loss 4.759e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.55e-01 s| kappa cost 4.13e-02 | source cost 6.31e-03 | chi sq 2.71e+02
# epoch 154 | train loss 5.241e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.55e-01 s| kappa cost 4.57e-02 | source cost 6.67e-03 | chi sq 2.40e+02
# epoch 155 | train loss 7.211e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.50e-01 s| kappa cost 6.50e-02 | source cost 7.07e-03 | chi sq 2.45e+02
# Saved checkpoint for step 157: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-32
# epoch 156 | train loss 9.725e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.48e-01 s| kappa cost 9.03e-02 | source cost 6.93e-03 | chi sq 2.63e+02
# epoch 157 | train loss 8.258e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.62e-01 s| kappa cost 7.51e-02 | source cost 7.43e-03 | chi sq 2.63e+02
# epoch 158 | train loss 8.324e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.35e-01 s| kappa cost 7.60e-02 | source cost 7.28e-03 | chi sq 2.73e+02
# epoch 159 | train loss 7.765e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.60e-01 s| kappa cost 7.03e-02 | source cost 7.32e-03 | chi sq 3.24e+02
# epoch 160 | train loss 7.882e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.50e-01 s| kappa cost 6.97e-02 | source cost 9.08e-03 | chi sq 3.11e+02
# Saved checkpoint for step 162: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-33
# epoch 161 | train loss 6.688e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.48e-01 s| kappa cost 5.82e-02 | source cost 8.70e-03 | chi sq 2.64e+02
# epoch 162 | train loss 5.378e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.61e-01 s| kappa cost 4.63e-02 | source cost 7.45e-03 | chi sq 2.36e+02
# epoch 163 | train loss 5.850e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.55e-01 s| kappa cost 5.20e-02 | source cost 6.53e-03 | chi sq 2.78e+02
# epoch 164 | train loss 5.918e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.66e-01 s| kappa cost 5.19e-02 | source cost 7.31e-03 | chi sq 2.92e+02
# epoch 165 | train loss 5.420e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 1.56e+00 s| kappa cost 4.50e-02 | source cost 9.17e-03 | chi sq 2.40e+02
# Saved checkpoint for step 167: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-34
# epoch 166 | train loss 7.246e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.52e-01 s| kappa cost 6.39e-02 | source cost 8.56e-03 | chi sq 2.42e+02
# epoch 167 | train loss 6.775e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.44e-01 s| kappa cost 6.14e-02 | source cost 6.39e-03 | chi sq 2.61e+02
# epoch 168 | train loss 7.122e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.54e-01 s| kappa cost 6.43e-02 | source cost 6.93e-03 | chi sq 3.03e+02
# epoch 169 | train loss 7.485e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5.60e-01 s| kappa cost 6.33e-02 | source cost 1.15e-02 | chi sq 3.11e+02
# epoch 170 | train loss 7.172e-02 | val loss 0.000e+00 | lr 1.00e-02 | time per step 5
/home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-44
# epoch 216 | train loss 3.944e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.42e-01 s| kappa cost 3.47e-02 | source cost 4.76e-03 | chi sq 2.19e+02
# epoch 217 | train loss 4.033e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.50e-01 s| kappa cost 3.54e-02 | source cost 4.96e-03 | chi sq 2.25e+02
# epoch 218 | train loss 4.034e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 6.30e-01 s| kappa cost 3.52e-02 | source cost 5.14e-03 | chi sq 2.46e+02
# epoch 219 | train loss 4.015e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.65e-01 s| kappa cost 3.49e-02 | source cost 5.29e-03 | chi sq 2.86e+02
# epoch 220 | train loss 3.821e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.64e-01 s| kappa cost 3.31e-02 | source cost 5.12e-03 | chi sq 2.86e+02
# Saved checkpoint for step 222: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-45
# epoch 221 | train loss 3.998e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.56e-01 s| kappa cost 3.50e-02 | source cost 4.97e-03 | chi sq 2.47e+02
# epoch 222 | train loss 4.239e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.47e-01 s| kappa cost 3.75e-02 | source cost 4.86e-03 | chi sq 2.11e+02
# epoch 223 | train loss 3.978e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.32e-01 s| kappa cost 3.49e-02 | source cost 4.91e-03 | chi sq 2.19e+02
# epoch 224 | train loss 3.835e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.47e-01 s| kappa cost 3.36e-02 | source cost 4.78e-03 | chi sq 2.48e+02
# epoch 225 | train loss 3.790e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 1.53e+00 s| kappa cost 3.32e-02 | source cost 4.67e-03 | chi sq 2.42e+02
# Saved checkpoint for step 227: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-46
# epoch 226 | train loss 3.798e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.41e-01 s| kappa cost 3.34e-02 | source cost 4.59e-03 | chi sq 2.36e+02
# epoch 227 | train loss 4.149e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.29e-01 s| kappa cost 3.67e-02 | source cost 4.74e-03 | chi sq 2.25e+02
# epoch 228 | train loss 3.858e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.37e-01 s| kappa cost 3.39e-02 | source cost 4.68e-03 | chi sq 2.55e+02
# epoch 229 | train loss 3.864e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.48e-01 s| kappa cost 3.40e-02 | source cost 4.67e-03 | chi sq 2.81e+02
# epoch 230 | train loss 3.838e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.49e-01 s| kappa cost 3.39e-02 | source cost 4.53e-03 | chi sq 2.91e+02
# Saved checkpoint for step 232: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-47
# epoch 231 | train loss 3.907e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.51e-01 s| kappa cost 3.45e-02 | source cost 4.52e-03 | chi sq 2.76e+02
# epoch 232 | train loss 4.024e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.50e-01 s| kappa cost 3.57e-02 | source cost 4.55e-03 | chi sq 2.65e+02
# epoch 233 | train loss 3.998e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.51e-01 s| kappa cost 3.54e-02 | source cost 4.54e-03 | chi sq 2.62e+02
# epoch 234 | train loss 3.960e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.58e-01 s| kappa cost 3.51e-02 | source cost 4.48e-03 | chi sq 2.88e+02
# epoch 235 | train loss 3.807e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.33e-01 s| kappa cost 3.35e-02 | source cost 4.54e-03 | chi sq 3.08e+02
# Saved checkpoint for step 237: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-48
# epoch 236 | train loss 3.823e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.47e-01 s| kappa cost 3.37e-02 | source cost 4.54e-03 | chi sq 3.05e+02
# epoch 237 | train loss 4.028e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.40e-01 s| kappa cost 3.58e-02 | source cost 4.46e-03 | chi sq 2.84e+02
# epoch 238 | train loss 4.113e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5
-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.49e-01 s| kappa cost 3.34e-02 | source cost 3.90e-03 | chi sq 3.08e+02
# epoch 262 | train loss 3.816e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.60e-01 s| kappa cost 3.42e-02 | source cost 4.00e-03 | chi sq 3.00e+02
# epoch 263 | train loss 3.769e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.77e-01 s| kappa cost 3.38e-02 | source cost 3.94e-03 | chi sq 2.91e+02
# epoch 264 | train loss 3.733e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.65e-01 s| kappa cost 3.33e-02 | source cost 4.02e-03 | chi sq 3.19e+02
# ...
# epoch 380 | train loss 3.506e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.69e-01 s| kappa cost 3.18e-02 | source cost 3.29e-03 | chi sq 3.04e+02
# Saved checkpoint for step 382: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-77
# epoch 381 | train loss 3.435e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.62e-01 s| kappa cost 3.13e-02 | source cost 3.10e-03 | chi sq 3.07e+02
# epoch 382 | train loss 3.373e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.54e-01 s| kappa cost 3.06e-02 | source cost 3.13e-03 | chi sq 2.78e+02
# epoch 383 | train loss 3.382e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.71e-01 s| kappa cost 3.06e-02 | source cost 3.18e-03 | chi sq 2.81e+02
# epoch 384 | train loss 3.333e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.75e-01 s| kappa cost 3.02e-02 | source cost 3.12e-03 | chi sq 2.98e+02
# epoch 385 | train loss 3.422e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 6.41e-01 s| kappa cost 3.11e-02 | source cost 3.09e-03 | chi sq 2.97e+02
# Saved checkpoint for step 387: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-78
# epoch 386 | train loss 3.475e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.97e-01 s| kappa cost 3.17e-02 | source cost 3.09e-03 | chi sq 2.98e+02
# epoch 387 | train loss 3.466e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.95e-01 s| kappa cost 3.15e-02 | source cost 3.14e-03 | chi sq 2.92e+02
# epoch 388 | train loss 3.466e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.85e-01 s| kappa cost 3.15e-02 | source cost 3.17e-03 | chi sq 2.96e+02
# epoch 389 | train loss 3.438e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 6.32e-01 s| kappa cost 3.12e-02 | source cost 3.15e-03 | chi sq 2.93e+02
# epoch 390 | train loss 3.611e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.66e-01 s| kappa cost 3.29e-02 | source cost 3.16e-03 | chi sq 2.43e+02
# Saved checkpoint for step 392: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-79
# epoch 391 | train loss 3.397e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.81e-01 s| kappa cost 3.09e-02 | source cost 3.03e-03 | chi sq 3.07e+02
# epoch 392 | train loss 3.368e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.94e-01 s| kappa cost 3.05e-02 | source cost 3.14e-03 | chi sq 3.07e+02
# epoch 393 | train loss 3.366e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.93e-01 s| kappa cost 3.05e-02 | source cost 3.16e-03 | chi sq 2.84e+02
# epoch 394 | train loss 3.438e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.91e-01 s| kappa cost 3.13e-02 | source cost 3.10e-03 | chi sq 2.59e+02
# epoch 395 | train loss 3.442e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.76e-01 s| kappa cost 3.13e-02 | source cost 3.11e-03 | chi sq 2.58e+02
# Saved checkpoint for step 397: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-80
# epoch 396 | train loss 3.399e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.72e-01 s| kappa cost 3.08e-02 | source cost 3.19e-03 | chi sq 2.83e+02
# epoch 397 | train loss 3.362e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.99e-01 s| kappa cost 3.05e-02 | source cost 3.17e-03 | chi sq 2.73e+02
# epoch 398 | train loss 3.423e-02 | val loss 0.000e+00 | lr 5.00e-03 | time per step 5.77e-01 s| kappa cost 3.12e-02 | source cost 3.03e-03 | chi sq 2.89e+02
# epoch 399 | train loss 3.452e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.83e-01 s| kappa cost 3.15e-02 | source cost 3.04e-03 | chi sq 3.00e+02
# epoch 400 | train loss 3.463e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 6.12e-01 s| kappa cost 3.15e-02 | source cost 3.16e-03 | chi sq 3.02e+02
# Saved checkpoint for step 402: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-81
# epoch 401 | train loss 3.486e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 6.09e-01 s| kappa cost 3.17e-02 | source cost 3.17e-03 | chi sq 2.99e+02
# epoch 402 | train loss 3.401e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.89e-01 s| kappa cost 3.09e-02 | source cost 3.08e-03 | chi sq 3.05e+02
# epoch 403 | train loss 3.423e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 6.03e-01 s| kappa cost 3.12e-02 | source cost 3.03e-03 | chi sq 2.92e+02
# epoch 404 | train loss 3.371e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.83e-01 s| kappa cost 3.06e-02 | source cost 3.08e-03 | chi sq 2.68e+02
# epoch 405 | train loss 3.381e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 1.67e+00 s| kappa cost 3.06e-02 | source cost 3.17e-03 | chi sq 2.48e+02
# Saved checkpoint for step 407: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-82
# epoch 406 | train loss 3.421e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.91e-01 s| kappa cost 3.10e-02 | source cost 3.20e-03 | chi sq 2.59e+02
# epoch 407 | train loss 3.383e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.75e-01 s| kappa cost 3.07e-02 | source cost 3.15e-03 | chi sq 2.71e+02
# epoch 408 | train loss 3.325e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.71e-01 s| kappa cost 3.02e-02 | source cost 3.07e-03 | chi sq 2.55e+02
# epoch 409 | train loss 3.376e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.84e-01 s| kappa cost 3.08e-02 | source cost 2.98e-03 | chi sq 2.76e+02
# epoch 410 | train loss 3.495e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.77e-01 s| kappa cost 3.19e-02 | source cost 3.02e-03 | chi sq 3.09e+02
# Saved checkpoint for step 412: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-83
# epoch 411 | train loss 3.498e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.58e-01 s| kappa cost 3.19e-02 | source cost 3.10e-03 | chi sq 3.11e+02
# epoch 412 | train loss 3.552e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.71e-01 s| kappa cost 3.23e-02 | source cost 3.20e-03 | chi sq 3.14e+02
# epoch 413 | train loss 3.561e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.96e-01 s| kappa cost 3.24e-02 | source cost 3.17e-03 | chi sq 3.09e+02
# epoch 414 | train loss 3.595e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.80e-01 s| kappa cost 3.28e-02 | source cost 3.11e-03 | chi sq 3.06e+02
# epoch 415 | train loss 3.659e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.59e-01 s| kappa cost 3.35e-02 | source cost 3.12e-03 | chi sq 2.87e+02
# Saved checkpoint for step 417: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-84
# epoch 416 | train loss 3.561e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.72e-01 s| kappa cost 3.24e-02 | source cost 3.20e-03 | chi sq 2.49e+02
# epoch 417 | train loss 3.247e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.92e-01 s| kappa cost 2.93e-02 | source cost 3.14e-03 | chi sq 2.69e+02
# epoch 418 | train loss 3.189e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.88e-01 s| kappa cost 2.87e-02 | source cost 3.14e-03 | chi sq 2.55e+02
# epoch 419 | train loss 3.433e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.74e-01 s| kappa cost 3.11e-02 | source cost 3.25e-03 | chi sq 2.26e+02
# epoch 420 | train loss 3.343e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.98e-01 s| kappa cost 3.03e-02 | source cost 3.12e-03 | chi sq 2.22e+02
# Saved checkpoint for step 422: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-85
# epoch 421 | train loss 3.264e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.79e-01 s| kappa cost 2.96e-02 | source cost 3.03e-03 | chi sq 2.51e+02
# epoch 422 | train loss 3.330e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.70e-01 s| kappa cost 3.02e-02 | source cost 3.05e-03 | chi sq 2.84e+02
# epoch 423 | train loss 3.365e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.69e-01 s| kappa cost 3.06e-02 | source cost 3.08e-03 | chi sq 3.12e+02
# epoch 424 | train loss 3.421e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.61e-01 s| kappa cost 3.11e-02 | source cost 3.10e-03 | chi sq 3.14e+02
# epoch 425 | train loss 3.518e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.56e-01 s| kappa cost 3.21e-02 | source cost 3.11e-03 | chi sq 3.18e+02
# Saved checkpoint for step 427: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-86
# epoch 426 | train loss 3.495e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 7.02e-01 s| kappa cost 3.19e-02 | source cost 3.04e-03 | chi sq 3.12e+02
# epoch 427 | train loss 3.611e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.58e-01 s| kappa cost 3.30e-02 | source cost 3.10e-03 | chi sq 3.07e+02
# epoch 428 | train loss 3.619e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.70e-01 s| kappa cost 3.30e-02 | source cost 3.15e-03 | chi sq 3.03e+02
# epoch 429 | train loss 3.592e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.50e-01 s| kappa cost 3.27e-02 | source cost 3.22e-03 | chi sq 2.96e+02
# epoch 430 | train loss 3.687e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.63e-01 s| kappa cost 3.36e-02 | source cost 3.26e-03 | chi sq 2.88e+02
# Saved checkpoint for step 432: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-87
# epoch 431 | train loss 3.523e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.73e-01 s| kappa cost 3.21e-02 | source cost 3.12e-03 | chi sq 2.94e+02
# epoch 432 | train loss 3.380e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.56e-01 s| kappa cost 3.07e-02 | source cost 3.11e-03 | chi sq 2.77e+02
# epoch 433 | train loss 3.312e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.46e-01 s| kappa cost 3.00e-02 | source cost 3.12e-03 | chi sq 2.74e+02
# epoch 434 | train loss 3.402e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.61e-01 s| kappa cost 3.09e-02 | source cost 3.13e-03 | chi sq 2.92e+02
# epoch 435 | train loss 3.489e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 1.64e+00 s| kappa cost 3.17e-02 | source cost 3.20e-03 | chi sq 2.97e+02
# Saved checkpoint for step 437: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-88
# epoch 436 | train loss 3.622e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.60e-01 s| kappa cost 3.30e-02 | source cost 3.22e-03 | chi sq 3.04e+02
# epoch 437 | train loss 3.664e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.45e-01 s| kappa cost 3.34e-02 | source cost 3.27e-03 | chi sq 3.11e+02
# epoch 438 | train loss 3.515e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.46e-01 s| kappa cost 3.18e-02 | source cost 3.36e-03 | chi sq 3.16e+02
# epoch 439 | train loss 3.572e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.53e-01 s| kappa cost 3.23e-02 | source cost 3.45e-03 | chi sq 3.11e+02
# epoch 440 | train loss 3.733e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.71e-01 s| kappa cost 3.39e-02 | source cost 3.45e-03 | chi sq 2.84e+02
# Saved checkpoint for step 442: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-89
# epoch 441 | train loss 3.787e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.51e-01 s| kappa cost 3.44e-02 | source cost 3.48e-03 | chi sq 2.47e+02
# epoch 442 | train loss 3.500e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.49e-01 s| kappa cost 3.15e-02 | source cost 3.48e-03 | chi sq 2.32e+02
# epoch 443 | train loss 3.277e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.55e-01 s| kappa cost 2.92e-02 | source cost 3.54e-03 | chi sq 2.13e+02
# epoch 444 | train loss 3.326e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.65e-01 s| kappa cost 2.98e-02 | source cost 3.43e-03 | chi sq 2.66e+02
# epoch 445 | train loss 3.329e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.69e-01 s| kappa cost 2.99e-02 | source cost 3.36e-03 | chi sq 2.56e+02
# Saved checkpoint for step 447: /home/aadam/scratch/Censai/models/RIMSU512_k128_hTNG_interactive_21-10-14_02-21-28/ckpt-90
# epoch 446 | train loss 3.438e-02 | val loss 0.000e+00 | lr 2.50e-03 | time per step 5.69e-01 s| kappa cost 3.09e-02 | source cost 3.43e-03 | chi sq 2.82e+02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-77dea8357083> in <module>
#      64 for cache in cache_files:
#      65     os.remove(cache)
# ---> 66 rim, phys, train_dataset, val_dataset = main(args)
#
# <ipython-input-2-c53f4d490bfc> in main(args)
#     252             for batch, (X, source, kappa) in enumerate(train_dataset):
#     253                 start = time.time()
# --> 254                 cost, chi_squared, source_cost, kappa_cost = train_step(X, source, kappa)
#     255         # ========== Summary and logs ==================================================================================
#     256                 _time = time.time() - start
#
# <ipython-input-2-c53f4d490bfc> in train_step(X, source, kappa)
#     154             tape.watch(rim.unet.trainable_variables)
#     155             if args.unroll_time_steps:
# --> 156                 source_series, kappa_series, chi_squared = rim.call_function(X)
#     157             else:
#     158                 source_series, kappa_series, chi_squared = rim.call(X, outer_tape=tape)
#
# ~/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1924     forward_function, args_with_tangents = forward_backward.forward()
#    1925     if executing_eagerly:
# -> 1926       flat_outputs = forward_function.call(
#    1927           ctx, args_with_tangents, cancellation_manager=cancellation_manager)
#    1928     else:
#
# ~/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
for batch, distributed_inputs in enumerate(train_dataset):
    for res_idx in range(args.batch_size):
        lens_true = distributed_inputs[0][res_idx]
        lens_true /= tf.reduce_max(lens_true, axis=(0, 1, 2), keepdims=True)
        source_true = distributed_inputs[1][res_idx]
        kappa_true = distributed_inputs[2][res_idx]
        source_pred, kappa_pred, chi_squared = rim.predict(lens_true[None])
        lens_pred = phys.forward(source_pred[-1], kappa_pred[-1])[0]
#         lens_pred = tf.nn.relu(lens_pred)
        lam = tf.reduce_sum(lens_true * lens_pred) / tf.reduce_sum(lens_pred**2)[..., tf.newaxis, tf.newaxis, tf.newaxis]
        fig = residual_plot(lens_true, source_true, kappa_true, lam*lens_pred, source_pred[-1][0, ...], kappa_pred[-1][0, ...], chi_squared[-1][0])
        fig.suptitle(fr"{batch}: Time step {args.steps+1}, $\chi^2 = ${chi_squared[-1][0]:.2e}")
    break

# %%
for X, source, kappa in train_dataset:
    break
self = rim
# self._kappa_init = args.kappa_init#0.9
# self._source_init = args.source_init
# self.physical_model.forward_method = "fft"
# self.adam = True
# self.beta_1 = 0.5
# self.beta_2 = 0.5
lensed_image = X
batch_size = lensed_image.shape[0]
source, kappa, states = self.initial_states(batch_size)
print(tf.reduce_mean(kappa))
source_series = tf.TensorArray(DTYPE, size=self.steps)
kappa_series = tf.TensorArray(DTYPE, size=self.steps)
chi_squared_series = tf.TensorArray(DTYPE, size=self.steps)
source_grad_series = tf.TensorArray(DTYPE, size=self.steps)
kappa_grad_series = tf.TensorArray(DTYPE, size=self.steps)
lens_series = tf.TensorArray(DTYPE, size=self.steps+1)

for current_step in range(self.steps):
#     kappa = self.kappa_link(kappa)
    with tf.GradientTape() as g:
        g.watch(source)
        g.watch(kappa)
        y_pred = self.physical_model.forward(source=self.source_link(source), kappa=self.kappa_link(kappa))
        log_likelihood = 0.5 * tf.reduce_sum((y_pred - lensed_image)**2/phys.noise_rms**2, axis=(1, 2, 3)) #+ 2000*tf.reduce_sum(source**2) #+ 100000*tf.reduce_sum(self.kappa_link(kappa))
        cost = tf.reduce_mean(log_likelihood)
    source_grad, kappa_grad = g.gradient(cost, [source, kappa])
#     source_grad, kappa_grad = [tf.clip_by_value(grad/1e2, -100, 100) for grad in [source_grad, kappa_grad]]
#     source_grad, kappa_grad = [tf.nn.tanh(grad) for grad in [source_grad, kappa_grad]]

    source_grad, kappa_grad = self.grad_update(source_grad, kappa_grad, current_step)
#     source, kappa, states = self.time_step(source, self.kappa_inverse_link(kappa), source_grad, kappa_grad, states)
    source, kappa, states = self.time_step(source, kappa, source_grad, kappa_grad, states)
    source_series = source_series.write(index=current_step, value=source)
    kappa_series = kappa_series.write(index=current_step, value=kappa)
    source_grad_series = source_grad_series.write(index=current_step, value=source_grad)
    kappa_grad_series = kappa_grad_series.write(index=current_step, value=kappa_grad)
    if current_step > 0:
        chi_squared_series = chi_squared_series.write(index=current_step-1, value=log_likelihood)
    lens_series.write(index=current_step, value=y_pred)
# last step score
y_pred = self.physical_model.forward(source=self.source_link(source), kappa=self.kappa_link(kappa))
log_likelihood = 0.5 * tf.reduce_sum((y_pred - lensed_image)**2/phys.noise_rms**2, axis=(1, 2, 3))
chi_squared_series = chi_squared_series.write(index=current_step, value=log_likelihood)
lens_series.write(index=current_step, value=y_pred)

s = source_series.stack()
k = kappa_series.stack()
grad_s = source_grad_series.stack()
grad_k = kappa_grad_series.stack()
lens = lens_series.stack()
# Out:
# tf.Tensor(-0.99567854, shape=(), dtype=float32)
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f0da51e80>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     return outflag  File "<ipython-input-78-8b3327405ad1>", line 46, in <module>
#     chi_squared_series = chi_squared_series.write(index=current_step, value=log_likelihood)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f0da51e80>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     return outflag  File "<ipython-input-78-8b3327405ad1>", line 46, in <module>
#     chi_squared_series = chi_squared_series.write(index=current_step, value=log_likelihood)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 42, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 47, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x2b0f1b3a5220>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-79-6c306b841b76>", line 47, in <module>
#     lens_series.write(index=current_step, value=y_pred)  File "/home/aadam/environments/censai3.8/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 247, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm, CenteredNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable


fig, axs = plt.subplots(args.steps, 5, figsize=(15, 3 * args.steps))
for i in range(args.steps):
    ax = axs[i, 0]
#     ax = axs[0]
    im = ax.imshow(grad_s[i, 0, ..., 0], cmap="seismic", norm=CenteredNorm(), origin="lower")
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    ax.axis("off")
    
    ax = axs[i, 1]
#     ax = axs[1]
    im = ax.imshow(s[i, 0, ..., 0], cmap="seismic", norm=CenteredNorm(), origin="lower")
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    ax.axis("off")
    
    ax = axs[i, 2]
#     ax = axs[1]
    im = ax.imshow(grad_k[i, 0, ..., 0], cmap="seismic", norm=CenteredNorm(), origin="lower")
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    ax.axis("off")
    
    ax = axs[i, 3]
#     ax = axs[1]
    im = ax.imshow(k[i, 0, ..., 0], cmap="hot", origin="lower")
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    ax.axis("off")
    
    ax = axs[i, 4]
#     ax = axs[1]
    im = ax.imshow(lens[i, 0, ..., 0], cmap="hot", origin="lower")
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    ax.axis("off")

# %%
# model_id = "RIMSU512_k128_NIE2nsvdO_007_TS10_F8_L4_IK7_NLrelu_al0.1_GAconcat_82_B10_lr0.0005_dr1.0_ds5000_TWquadratic_210923024919"
# import sys
# sys.argv = ['']
# args = parser.parse_args(
#   f"--model_id={os.getenv('CENSAI_PATH')}/models/{model_id} "\
#   f"--datasets {os.getenv('CENSAI_PATH')}/data/lenses512_hk128_TNG100_10k_verydiffuse "\
#   f"--compression_type=GZIP "\
#   f"--forward_method=fft "\
#   f"--optimizer=ADAM "\
#   f"--epochs=200 "\
#   f"--max_time=1 "\
#   f"--initial_learning_rate=1e-3 "\
#   f"--decay_rate=0.5 "\
#   f"--decay_steps=100 "\
#   f"--staircase "\
#   f"--clipping "\
#   f"--patience=20 "\
#   f"--tolerance=0.01 "\
#   f"--batch_size=10 "\
#   f"--train_split=1 "\
#   f"--total_items=1000 "\
#   f"--block_length=1 "\
#   f"--buffer_size=1000 "\
# #   f"--steps=10 "\
# #   f"--adam "\
# #   f"--kappalog "\
# #   f"--source_link=lrelu4p "\
# #   f"--filters=16 "\
# #   f"--filter_scaling=1.5 "\
# #   f"--kernel_size=3 "\
# #   f"--layers=5 "\
# #   f"--block_conv_layers=2 "\
# #   f"--resampling_kernel_size=3 "\
# #   f"--gru_kernel_size=3 "\
# #   f"--batch_norm "\
# #   f"--dropout=0.1 "\
# #   f"--upsampling_interpolation "\
# #   f"--kernel_l2_amp=1e-4 "\
# #   f"--bias_l2_amp=1e-4 "\
# #   f"--kernel_l1_amp=1e-3 "\5e-3
# #   f"--bias_l1_amp=1e-3 "\
# #   f"--activation=leaky_relu "\
# #   f"--alpha=0.3 "\
#   f"--cache_file={os.getenv('SLURM_TMPDIR')}/cache "\
#   f"--logdir={os.getenv('HOME')}/scratch/Censai/logs "\
#   f"--logname=RIMSU512_k128_pretrained_hTNG "\
#   f"--track_train "\
#   f"--model_dir={os.getenv('HOME')}/scratch/Censai/models "\
#   f"--checkpoints=5 "\
#   f"--max_to_keep=3 "\
#   f"--seed=42 "\
#   f"--n_residuals=0 "\
#   f"--json_override {os.getenv('CENSAI_PATH')}/models/{model_id}/unet_hparams.json {os.getenv('CENSAI_PATH')}/models/{model_id}/rim_hparams.json".split()

# )
# if args.json_override is not None:
#     if isinstance(args.json_override, list):
#         files = args.json_override
#     else:
#         files = [args.json_override,]
#     for file in files:
#         with open(file, "r") as f:
#             json_override = json.load(f)
#         args_dict = vars(args)
#         args_dict.update(json_override)
# cache_files = glob.glob(f"{os.getenv('SLURM_TMPDIR')}/cache*")
# for cache in cache_files:
#     os.remove(cache)
# rim, phys, train_dataset, val_dataset = main(args)
