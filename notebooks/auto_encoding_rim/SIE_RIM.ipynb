# %%
import sys
sys.path = ['',
 '/cm/shared/sw/pkg-old/devel/python2/2.7.13/bin',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python27.zip',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/plat-linux2',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/lib-tk',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/lib-old',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/lib-dynload',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages',
 '/mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/IPython/extensions',
 '/mnt/home/llevasseur/.ipython']

# %%
import tensorflow as tf
import numpy as np

tf.enable_eager_execution()
# Out:
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
execfile("AE_RIM_definitions.py")

train_batch_size = 1
num_steps = 4
num_features = 512
state_size = 128

load_checkpoint_path_1 = "checkpoints/model1_512_N10_FFCNN"
load_checkpoint_path_2 = "checkpoints/model2_512_N10_FFCNN"
RESTORE=True
save_checkpoint_path_1 = "checkpoints/model1_512_N10_FFCNN"
save_checkpoint_path_2 = "checkpoints/model2_512_N10_FFCNN"


import matplotlib.pyplot as plt
# %matplotlib inline  
from IPython import display
import pylab as pl

# %%
src_side = 20.48/2
im_side = 20.48

sk_gen = SRC_KAPPA_Generator(train_batch_size=train_batch_size,test_batch_size=train_batch_size,kap_side_length=im_side, num_src_side=num_features,num_kappa_side=num_features,src_side=src_side)
src_in , kap_in = sk_gen.draw_average_k_s()

RIM = RIM_UNET_CELL(train_batch_size , num_steps , num_features , state_size)
lens_util_obj = lens_util(im_side= im_side, src_side=src_side, numpix_side = num_features ,kap_side=im_side,  method = "Unet")

physical_model = lens_util_obj.physical_model
noise_rms = 0.01
sk_gen.draw_k_s("test")

if (RESTORE):
    RIM.model_1.load_weights(load_checkpoint_path_1)
    RIM.model_2.load_weights(load_checkpoint_path_2)

# %%
FFCNN = FFCNN()
FFCNN.Load()

# %%
optimizer = tf.train.AdamOptimizer(5e-5)

# %%
for train_iter in range(4000000):
    print train_iter
    sk_gen.draw_k_s("train")
    noisy_data = lens_util_obj.simulate_noisy_lensed_image(  sk_gen.Source_tr[:,:,:,:],np.log10(sk_gen.Kappa_tr[:,:,:,:]),noise_rms)
    tf_source =  tf.identity(sk_gen.Source_tr[:,:,:,:])
    tf_logkappa  = log10(tf.identity(sk_gen.Kappa_tr[:,:,:,:]) )
    #logkappa_first_guess = FFCNN.fullforward_pass(noisy_data) 
    logkappa_first_guess = tf_logkappa

    with tf.GradientTape() as tape:
        tape.watch(RIM.model_1.variables)
        tape.watch(RIM.model_2.variables)
        cost_value, _ , _ , OS_src , OS_kap = RIM.cost_function(noisy_data, tf_source , tf_logkappa , logkappa_first_guess*0. , logkappa_first_guess)
    weight_grads = tape.gradient(cost_value, [RIM.model_1.variables , RIM.model_2.variables] )

    clipped_grads_1 = [tf.clip_by_value(grads_i,-10,10) for grads_i in weight_grads[0]]
    optimizer.apply_gradients(zip(clipped_grads_1, RIM.model_1.variables), global_step=tf.train.get_or_create_global_step())
    clipped_grads_2 = [tf.clip_by_value(grads_i,-10,10) for grads_i in weight_grads[1]]
    optimizer.apply_gradients(zip(clipped_grads_2, RIM.model_2.variables), global_step=tf.train.get_or_create_global_step())
    print( train_iter , cost_value.numpy() )
    if (((train_iter+1)%1)==0):
        model_im = lens_util_obj.physical_model(OS_src , OS_kap)
        pl.clf()
        fig, ax = pl.subplots(3, 2, figsize = (10, 15))
        pl.subplots_adjust(wspace = 0, hspace = 0)
        imsrcP = ax[0, 0].imshow(OS_src[0,:,:,0])
        immodP = ax[0, 1].imshow(OS_kap[0,:,:,0])
        imsrcT = ax[1, 0].imshow(tf_source[0,:,:,0])
        imsrcT = ax[1, 1].imshow(tf_logkappa[0,:,:,0])
        immodT = ax[2, 0].imshow(noisy_data[0,:,:,0])
        immodP = ax[2, 1].imshow(model_im.numpy()[0,:,:,0])
        for j in range(2):
            for i in range(3):
                ax[i,j].axis('off')    
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print( train_iter , cost_value.numpy() )
#     if (((train_iter+1)%100)==0):
#         RIM.model_1.save_weights(checkpoint_path_1)
#         RIM.model_2.save_weights(checkpoint_path_2)
#         print('saved weights.')

            
# for train_iter in range(4000):
#     #if ((train_iter%1)==0):
#     print train_iter
#     sk_gen.draw_k_s("train")
#     noisy_data = lens_util_obj.simulate_noisy_lensed_image(  sk_gen.Source_tr[:,:,:,:],sk_gen.Kappa_tr[:,:,:,:],noise_rms)
#     tf_source =  tf.identity(sk_gen.Source_tr[:,:,:,:])
#     tf_kappa  = tf.identity(sk_gen.Kappa_tr[:,:,:,:] )

#     logkappa_first_guess = FFCNN.fullforward_pass(noisy_data)  

#     with tf.GradientTape() as tape:
#         tape.watch(RIM.model_1.variables)
#         #tape.watch(RIM.model_2.variables)
#         cost_value, _ , _ , OS_src , OS_kap = RIM.cost_function(noisy_data, tf_source , tf_kappa , logkappa_first_guess*0. , logkappa_first_guess)
#     weight_grads = tape.gradient(cost_value, [RIM.model_1.variables ] )

#     clipped_grads_1 = [tf.clip_by_value(grads_i,-10,10) for grads_i in weight_grads[0]]
#     optimizer.apply_gradients(zip(clipped_grads_1, RIM.model_1.variables), global_step=tf.train.get_or_create_global_step())
# #     clipped_grads_2 = [tf.clip_by_value(grads_i,-10,10) for grads_i in weight_grads[1]]
# #     optimizer.apply_gradients(zip(clipped_grads_2, RIM.model_2.variables), global_step=tf.train.get_or_create_global_step())
#     print( train_iter , cost_value.numpy() )
#     if (((train_iter+1)%1)==0):
#         model_im = lens_util_obj.physical_model(OS_src , OS_kap)
#         pl.clf()
#         fig, ax = pl.subplots(3, 2, figsize = (10, 15))
#         pl.subplots_adjust(wspace = 0, hspace = 0)
#         imsrcP = ax[0, 0].imshow(OS_src[0,:,:,0])
# #         immodP = ax[0, 1].imshow(np.log10(OS_kap[0,:,:,0]))
#         imsrcT = ax[1, 0].imshow(tf_source[0,:,:,0])
# #         imsrcT = ax[1, 1].imshow(np.log10(tf_kappa[0,:,:,0]))
#         immodT = ax[2, 0].imshow(noisy_data[0,:,:,0])
#         immodP = ax[2, 1].imshow(model_im.numpy()[0,:,:,0])
#         for j in range(2):
#             for i in range(3):
#                 ax[i,j].axis('off')    
#         display.clear_output(wait=True)
#         display.display(pl.gcf())
#         print( train_iter , cost_value.numpy() )
# #     if (((train_iter+1)%100)==0):
# #         RIM.model_1.save_weights(checkpoint_path_1)
# #         RIM.model_2.save_weights(checkpoint_path_2)
# #         print('saved weights.')
# Out:
# (23, 7.884292e-05)
# 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-631dc8b1b7d2> in <module>()
#      11         tape.watch(RIM.model_1.variables)
#      12         tape.watch(RIM.model_2.variables)
# ---> 13         cost_value, _ , _ , OS_src , OS_kap = RIM.cost_function(noisy_data, tf_source , tf_logkappa , logkappa_first_guess*0. , logkappa_first_guess)
#      14     weight_grads = tape.gradient(cost_value, [RIM.model_1.variables , RIM.model_2.variables] )
#      15
#
# /mnt/home/llevasseur/Censai/notebooks/auto_encoding_rim/AE_RIM_definitions.py in cost_function(self, data, labels_x_1, labels_x_2, starting_guess_1, starting_guess_2)
#     619         if starting_guess_2 is not None:
#     620             self.inputs_2 = starting_guess_2
# --> 621         output_series_1 , output_series_2 , final_log_L = self.forward_pass(data)
#     622         return tf.reduce_mean(tf.square(output_series_1 - labels_x_1)) + tf.reduce_mean(tf.square(output_series_2 - labels_x_2)), output_series_1 , output_series_2 , output_series_1[-1].numpy() , output_series_2[-1].numpy()
#     623
#
# /mnt/home/llevasseur/Censai/notebooks/auto_encoding_rim/AE_RIM_definitions.py in forward_pass(self, data)
#     608
#     609
# --> 610             output_1, state_1 , output_2 , state_2 = self.__call__(output_1, state_1 , grads[0] , output_2 , state_2 , grads[1])
#     611             output_series_1.append(output_1)
#     612             output_series_2.append(output_2)
#
# /mnt/home/llevasseur/Censai/notebooks/auto_encoding_rim/AE_RIM_definitions.py in __call__(self, inputs_1, state_1, grad_1, inputs_2, state_2, grad_2, scope)
#     581
#     582     def __call__(self, inputs_1, state_1, grad_1, inputs_2, state_2, grad_2 , scope=None):
# --> 583         xt_1, ht_1 = self.model_1(inputs_1, state_1 , grad_1)
#     584         xt_2, ht_2 = self.model_2(inputs_2, state_2 , grad_2)
#     585         return xt_1, ht_1, xt_2, ht_2
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/keras/engine/base_layer.pyc in __call__(self, inputs, *args, **kwargs)
#     734
#     735       if not in_deferred_mode:
# --> 736         outputs = self.call(inputs, *args, **kwargs)
#     737         if outputs is None:
#     738           raise ValueError('A layer\'s `call` method should return a Tensor '
#
# /mnt/home/llevasseur/Censai/notebooks/auto_encoding_rim/AE_RIM_definitions.py in call(self, inputs, state, grad)
#     484         p1 = self.Lp13 (c1)
#     485         c2 = self.Lc21 (p1)
# --> 486         c2 = self.Lc22 (c2)
#     487         c2_gru , c2_gru_state = self.GRU_COMP2(c2 , ht_2)
#     488
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/keras/engine/base_layer.pyc in __call__(self, inputs, *args, **kwargs)
#     734
#     735       if not in_deferred_mode:
# --> 736         outputs = self.call(inputs, *args, **kwargs)
#     737         if outputs is None:
#     738           raise ValueError('A layer\'s `call` method should return a Tensor '
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/keras/layers/convolutional.pyc in call(self, inputs)
#     184
#     185   def call(self, inputs):
# --> 186     outputs = self._convolution_op(inputs, self.kernel)
#     187
#     188     if self.use_bias:
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in __call__(self, inp, filter)
#     866
#     867   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 868     return self.conv_op(inp, filter)
#     869
#     870
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in __call__(self, inp, filter)
#     518
#     519   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 520     return self.call(inp, filter)
#     521
#     522
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in __call__(self, inp, filter)
#     202         padding=self.padding,
#     203         data_format=self.data_format,
# --> 204         name=self.name)
#     205
#     206
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/ops/gen_nn_ops.pyc in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name)
#     979           input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#     980           padding=padding, data_format=data_format, dilations=dilations,
# --> 981           name=name, ctx=_ctx)
#     982     except _core._NotOkStatusException as e:
#     983       if name is not None:
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/ops/gen_nn_ops.pyc in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name, ctx)
#    1019   "dilations", dilations)
#    1020   _result = _execute.execute(b"Conv2D", 1, inputs=_inputs_flat, attrs=_attrs,
# -> 1021                              ctx=_ctx, name=name)
#    1022   _execute.record_gradient(
#    1023       "Conv2D", _inputs_flat, _attrs, _result, name)
#
# /mnt/xfs1/flatiron-sw/pkg/devel/python2/2.7.13/lib/python2.7/site-packages/tensorflow/python/eager/execute.pyc in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      59                                                op_name, inputs, attrs,
# ---> 60                                                num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model_im = lens_util_obj.physical_model(OS_src , OS_kap)
pl.clf()
fig, ax = pl.subplots(3, 2, figsize = (10, 15))
pl.subplots_adjust(wspace = 0, hspace = 0)
imsrcP = ax[0, 0].imshow(OS_src[0,:,:,0])
immodP = ax[0, 1].imshow(OS_kap[0,:,:,0])
imsrcT = ax[1, 0].imshow(tf_source[0,:,:,0])
imsrcT = ax[1, 1].imshow(np.log10(tf_kappa[0,:,:,0]))
immodT = ax[2, 0].imshow(noisy_data[0,:,:,0])
immodP = ax[2, 1].imshow(model_im.numpy()[0,:,:,0])
for j in range(2):
    for i in range(3):
        ax[i,j].axis('off')    
display.clear_output(wait=True)
# display.display(pl.gcf())

# %%
len(OS_src)

# %%
len(cost_value)

# %%
plt.figure()
plt.imshow(tf_source.numpy()[0,:,:,0])
plt.figure()
plt.imshow(np.log10(tf_kappa.numpy()[0,:,:,0]))
plt.figure()
plt.imshow(noisy_data.numpy()[0,:,:,0])

# %%
xs , ys , ax , ay = lens_util_obj.get_deflection_angles(tf_kappa)

# %%
plt.plot(xs[0,:,:,0],ys[0,:,:,0],' .');

# %%
plt.imshow(ay[0,:,:,0])

# %%
from skimage.transform import resize

# %%
execfile("genSIEdef_angles.py")

# %%
train_batch_size = 10
num_features = 512


RT = RayTracer()
kap_gen = SRC_KAPPA_Generator(train_batch_size=train_batch_size,kap_side_length=20.48,num_src_side=num_features,num_kappa_side=num_features)
checkpoint_path = "checkpoints/model_Unet"
RT.load_weights(checkpoint_path)

# %%
ALFA = RT(tf_kappa)

# %%
plt.imshow(ALFA[0,:,:,1])

# %%
np.save('np_kappa.npy',tf_kappa.numpy())

# %%
plt.imshow(np.log10(tf_kappa[0,:,:,0]))
