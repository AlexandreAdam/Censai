# %%
import numpy as np
from astropy.io import fits
import os, glob
import galsim
import tensorflow as tf
import tensorflow_addons as tfa
from censai.data.cosmos import decode, preprocess
import matplotlib.pyplot as plt
from astropy.visualization import LogStretch, ImageNormalize
from mpl_toolkits.axes_grid1 import make_axes_locatable
from censai.physical_model import PhysicalModel
from astropy.cosmology import Planck18 as cosmo
from astropy.constants import c, G,  M_sun
from astropy import units as u
from scipy.signal import tukey
import pandas as pd

# %%
pixels = 208
pixel_scale = 0.03
fov = pixels * pixel_scale

x = np.linspace(-1, 1, pixels) * fov
xx, yy = np.meshgrid(x, x)
def get_flux(image, hlr):
    sigma = hlr / 2 / np.log(2 * np.sqrt(2)) # hlr is fwhm of profile
    window = np.exp(-0.5 * (xx**2 + yy**2) / sigma**2)
    window /= window.sum()
    flux = np.sum(window * image)
    return flux

# %% [markdown]
# ### Window for source

# %%
window = tukey(128, alpha=0.4)
window = np.outer(window, window)
plt.imshow(window)
window = window[np.newaxis, ..., np.newaxis]

# %% [markdown]
# # Exploration of catalog

# %%
catalog = galsim.COSMOSCatalog(sample="23.5", dir="/home/aadam/scratch/data/COSMOS/COSMOS_23.5_training_sample", exclusion_level="marginal", min_flux=50)
# catalog = galsim.COSMOSCatalog(sample="25.2", dir="/home/aadam/scratch/data/COSMOS/COSMOS_25.2_training_sample", exclusion_level="marginal", min_hlr=2)
cat_param = catalog.param_cat[catalog.orig_index]

# %%
catalog.getNObjects()
# Out:
# 13321

# %%
def logit(x):
    """
    Computes the logit function, i.e. the logistic sigmoid inverse.
    This function has no gradient, so it cannot be used on model output. It is mainly used
    to link physical labels to model labels.

    We clip values for numerical stability.
    Normally, there should not be any values outside of this range anyway, except maybe for the peak at 1.
    """
    x = tf.math.minimum(x, 1.-1e-3)
    x = tf.math.maximum(x, 1e-3)
    return - tf.math.log(1. / x - 1.)

# %%
# basic drawing, no modification
# ind = 2499
# ind = 161
ind = 6459
# ind = 13003


gal = catalog.makeGalaxy(ind, gal_type='real', noise_pad_size=1*pixels * pixel_scale)
psf = gal.original_psf
gal = galsim.Convolve(gal, psf)
plt.imshow(gal.drawImage().array, cmap="hot")

plt.colorbar()

# %%
im = gal.drawImage().array
im = tf.nn.relu(im - 3e-3)
im /= tf.reduce_max(im)
plt.imshow(logit(im), cmap="seismic")
plt.colorbar()

# %%
plt.hist(np.log10(cat_param["flux"][:, 0][cat_param["flux"][:, 0] > 1e-1]), bins=200);

# %%
np.where(cat_param["flux"][:, 0] < 101 )
# Out:
# (array([    0,     1,     5, ..., 13310, 13313, 13319]),)

# %%
cat_param["hlr"][:, 0] # sersic half light radius
# cat_param
# Out:
# array([0.70258482, 0.7637169 , 0.50824079, ..., 0.64909972, 0.47805683,
#        0.60721601])

# %%
# cat_param["flux"][:, 0]

# %%
# draw on a fixed size stamp
im = gal.drawImage(nx=pixels, ny=pixels, scale=0.03, method='no_pixel', use_true_center=False).array.astype('float32')
# plt.imshow(im, cmap="bone", norm=ImageNormalize(stretch=LogStretch()))
plt.imshow(im)

# %%
# # hlr = gal.calculateHLR()
# hlr = cat_param["hlr"][ind, 0]
# sigma = hlr / 2 / np.log(2 * np.sqrt(2)) # hlr is fwhm of profile
# window = np.exp(-0.5 * (xx**2 + yy**2) / sigma**2)
# window /= window.sum()
# plt.imshow(window * im)
# hlr

# %% [markdown]
# ##### some interesting examples from the cosmos dataset 25.2
# ##### indices = [81005,80252,80203]

# %%
zd = 0.44
zs = 2.37
Ds = cosmo.angular_diameter_distance(zs)
Dd = cosmo.angular_diameter_distance(zd)
Dds = cosmo.angular_diameter_distance_z1z2(zd, zs)
sigma_crit = (c**2 * Ds / (4 * np.pi * G * Dd * Dds) / (1e10 * M_sun)).to(u.Mpc**(-2)).value
sigma_crit
# Out:
# 196395.08907612518

# %%
ratio = 226713.6059585938 / sigma_crit 
ratio
# Out:
# 1.1543751273267164

# %%
raw_datapath = "/home/aadam/scratch/data/COSMOS/COSMOS_25.2_training_sample"
tfrecords_datapath = "/home/aadam/scratch/Censai/data/cosmos_25.2/"
sample_tfrecord = os.path.join(tfrecords_datapath, "cosmos_record_80.tfrecords")

kappa_datapath = "/home/aadam/scratch/Censai/data/kappa158_TNG100_512/"

# %%
galaxy_data = tf.data.TFRecordDataset(sample_tfrecord).map(decode).map(preprocess)
galaxies = []
for (g, psf, ps) in galaxy_data:
#     print(np.sqrt(np.exp(ps[ps < 10].numpy().max())))
    galaxies.append(g)
#     break

# %%
kappa_data = []
i = 0
for file in os.listdir(kappa_datapath):
    kappa_data.append(fits.open(os.path.join(kappa_datapath, file)))
    if i == 100:
        break
    i += 1

# %%
header = kappa_data[0]["PRIMARY"].header
header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  158
# NAXIS2  =                  158
# SUBID   =               263558
# MASS    =    359.7749469066084 / Total mass in the subhalo, in 10^{10} solar mas
# CUTMASS =    260.2200073631043 / Total mass in the cutout in 10^{10} solar mass
# CREATED = '21-07-31_10-45-07'
# OFFSET0 =            665044610
# OFFSET1 =           1057321146
# OFFSET4 =            183355060
# OFFSET5 =                 4342
# FOV     =                  0.2 / Field of view in Mpc
# CD1_1   =   0.1361399186683572 / Pixel scale in arcsec for x dimension
# CD2_2   =   0.1361399186683572 / Pixel scale in arcsec for y dimension
# CD1_2   =                  0.0
# CD2_1   =                  0.0
# XDIM    =                    1
# YDIM    =                    2
# XCENTER =    46.50489440283741 / Mpc, Comoving coordinate in the simulation
# YCENTER =    25.97951227208642 / Mpc, Comoving coordinate in the simulation
# NPART   =               918423 / Total number of particles
# NGAS    =                96365
# NDM     =               673620
# NSTARS  =               148437
# NBH     =                    1
# NSELECT =               685466 / Number of particles in the cutout
# ZSOURCE =                  1.5
# ZLENS   =                  0.5
# NNEIGH  =                   64
# FWPARAM =                  3.0 / FW at (1/x) maximum for smoothing
# SIGCRIT =    226713.6059585938
# COSMO   = 'Planck18'

# %%
# estimate einstein ring for a given kappa map
z_s = 2.37
z_d = 0.44
Dd = cosmo.angular_diameter_distance(z_d)
Ds = cosmo.angular_diameter_distance(z_s)
Dds = cosmo.angular_diameter_distance_z1z2(z_d, z_s)
M = header["CUTMASS"] * 1e10 * M_sun
theta_e = (np.sqrt(4 * G / c**2 * M * Dds / Ds / Dd).decompose() * u.rad).to(u.arcsec)
theta_e
# Out:
# <Quantity 3.50335951 arcsec>

# %%
# fov of kappa map given redshift and the chosen comoving size of the grids
fov_arcsec = header["CD1_1"] * 128
fov_arcsec
# Out:
# 17.425909589549722

# %%
physical_fov = header["FOV"] / header["NAXIS1"] * 128 * u.Mpc
physical_fov
# Out:
# <Quantity 0.16202532 Mpc>

# %%
m = [g.numpy().max() for g in galaxies]

# %%
[(_m, i) for i, _m in enumerate(m) if _m > 0.5]
# Out:
# [(0.80964667, 14),
#  (0.5257895, 89),
#  (0.9720869, 98),
#  (0.64894766, 253),
#  (1.1765397, 261),
#  (0.6556503, 307),
#  (1.2032963, 349),
#  (0.78535867, 355),
#  (1.4817048, 385),
#  (0.6626011, 403),
#  (0.5131483, 557),
#  (0.5293219, 601),
#  (0.50553554, 651),
#  (1.9971269, 701),
#  (2.0204146, 783),
#  (0.87531227, 786),
#  (1.2429297, 807),
#  (0.92020285, 830),
#  (1.6901392, 873),
#  (0.6991334, 959),
#  (0.7776954, 994)]

# %%
kap_id = 8
# kap_id = 3
# kap_id = 5
# kap_id =9
# gal_id = 203
# gal_id = 783
# gal_id = 994
gal_id = 10

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(4, 8))

im = ax1.imshow(kappa_data[kap_id][0].data, cmap="hot_r", norm=ImageNormalize(stretch=LogStretch()))
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='5%', pad=0.05)
cbar = fig.colorbar(im, cax=cax, orientation='vertical')
cbar.ax.locator_params(nbins=3)
ax1.contour(kappa_data[kap_id][0].data, levels=[1, 2])
ax1.axis("off");

im = ax2.imshow(window[0] * galaxies[gal_id], cmap="bone")#, norm=ImageNormalize(stretch=LogStretch()))
# im = ax2.imshow(np.arcsinh(galaxies[gal_id]), cmap="gray")
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im, cax=cax, orientation='vertical')
ax2.axis("off");

# %%
_kap_id = 8
shift_center = np.array([0, 0])
sigma_crit = (c**2 * Ds / (4 * np.pi * G * Dd * Dds)).to(u.kg * u.Mpc**(-2))


kap = kappa_data[_kap_id][0].data[50 + shift_center[0]: -(50 - shift_center[0]), 50 + shift_center[1]: -(50 - shift_center[1])][np.newaxis, ..., np.newaxis]
M = np.sum(kap[kap > 1]) * sigma_crit * (physical_fov/512)**2
theta_e = (np.sqrt(4 * G / c**2 * M * Dds / Ds / Dd).decompose() * u.rad).to(u.arcsec).value

thetas = []
tmax = 0.35 * 20
tmin = 0.05 * 20
print(tmax/theta_e)
print(kap.max())
rs = np.linspace(tmin/theta_e, tmax/theta_e, 100)
sigma_crit = (c**2 * Ds / (4 * np.pi * G * Dd * Dds)).to(u.kg * u.Mpc**(-2))
shift_center = [0, 0]

# rescaling vs einstein radius
for r in rs:
    kap = r * kappa_data[_kap_id][0].data[50 + shift_center[0]: -(50 - shift_center[0]), 50 + shift_center[1]: -(50 - shift_center[1])][np.newaxis, ..., np.newaxis]
    M = np.sum(kap[kap > 1]) * sigma_crit * (physical_fov/kap.shape[1])**2
    theta_e = (np.sqrt(4 * G / c**2 * M * Dds / Ds / Dd).decompose() * u.rad).to(u.arcsec).value
    thetas.append(theta_e)
plt.plot(rs, thetas)
# Out:
# 66.24799652793945
# 5.0456653

# %%
number_in_money = np.zeros(100)
tmax = 0.35 * 20
tmin = 0.05 * 20
for i in range(100):
    # rescaling vs einstein radius
    thetas = []
    kap = kappa_data[i][0].data[50 + shift_center[0]: -(50 - shift_center[0]), 50 + shift_center[1]: -(50 - shift_center[1])][np.newaxis, ..., np.newaxis]
    if kap.max() < 1:
        kap /= 0.9 * kap.max()
    M = np.sum(kap[kap > 1]) * sigma_crit * (physical_fov/kap.shape[1])**2
    theta_e = (np.sqrt(4 * G / c**2 * M * Dds / Ds / Dd).decompose() * u.rad).to(u.arcsec).value
    rs = np.linspace(tmin/theta_e, tmax/theta_e, 100)
    for r in rs:
        kap = r * kappa_data[i][0].data[50 + shift_center[0]: -(50 - shift_center[0]), 50 + shift_center[1]: -(50 - shift_center[1])][np.newaxis, ..., np.newaxis]
        M = np.sum(kap[kap > 1]) * sigma_crit * (physical_fov/kap.shape[1])**2
        theta_e = (np.sqrt(4 * G / c**2 * M * Dds / Ds / Dd).decompose() * u.rad).to(u.arcsec).value
        thetas.append(theta_e)
        number_in_money[i] += 1 if theta_e >= 1 and theta_e <= 5 else 0
    if number_in_money[i] == 0:
        print(theta_e)

# %%
plt.hist(number_in_money);

# %%
shift_center = [0, 0] # max 50 pixel shift
p_shift = 15
kap = 25*kappa_data[kap_id][0].data[p_shift + shift_center[0]: -(p_shift - shift_center[0]), p_shift + shift_center[1]: -(p_shift - shift_center[1])][np.newaxis, ..., np.newaxis]

M = np.sum(kap[kap > 1]) * sigma_crit * (physical_fov/kap.shape[1])**2
theta_e = (np.sqrt(4 * G / c**2 * M * Dds / Ds / Dd).decompose() * u.rad).to(u.arcsec).value
print(theta_e)
plt.imshow(kap[0, ..., 0], cmap="hot_r", norm=ImageNormalize(stretch=LogStretch()))
# Out:
# 6.685331206473817

# %%
image_fov = 20
source = window * galaxies[gal_id][np.newaxis, ...]
# source = tf.random.normal([1, 128, 128, 1])


phys = PhysicalModel(psf_sigma=0.08, image_fov=image_fov, src_fov=3, pixels=512, src_pixels=128, kappa_pixels=128, kappa_fov=fov_arcsec, method="conv2d")
lens = phys.noisy_forward(source=source, kappa=kap, noise_rms=3e-3) # 3e-3

# %%
plt.figure(figsize=(16, 16))
plt.imshow(lens[0, ..., 0], cmap="hot", extent=[-image_fov/2, image_fov/2]*2)#, norm=ImageNormalize(stretch=LogStretch()))
plt.axvline(theta_e, lw=2, color="w")
# plt.axis("off");

# %%
phys = PhysicalModel(psf_sigma=0.06, image_fov=image_fov, src_fov=3, pixels=512, src_pixels=128, kappa_pixels=128, kappa_fov=fov, method="conv2d")
ncol=5
nrow=5

fig, axs = plt.subplots(ncol, nrow, figsize=(20, 20))
for i in range(ncol):
    for j in range(nrow):      
        shift_center = [5*i, 5*j] # max 50 pixel shift
        kap = 12 * kappa_data[kap_id][0].data[50 + shift_center[0]: -(50 - shift_center[0]), 50 + shift_center[1]: -(50 - shift_center[1])][np.newaxis, ..., np.newaxis]
        lens = phys.noisy_forward(source=window * galaxies[gal_id][np.newaxis, ...], kappa=kap, noise_rms=6e-3)
        axs[i, j].imshow(lens[0, ..., 0], cmap="hot")
        axs[i, j].axis("off")
        
plt.subplots_adjust(wspace=.0, hspace=.0)

# %%
im, jac = phys.lens_source_and_compute_jacobian(source=galaxies[gal_id][np.newaxis, ...], kappa=kap*10)

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 8))
for i in range(2):
    for j in range(2):
        axs[i, j].imshow(np.arcsinh(jac[0, ..., i, j]))
        axs[i, j].axis("off")
# plt.subplots_adjust(wspace=.0, hspace=.0)

# %%
jac_det = tf.linalg.det(jac)
plt.imshow(np.arcsinh(jac_det[0]), cmap="hot_r")
plt.colorbar()
plt.contour(jac_det[0], levels=[0], cmap="jet")
# plt.imshow(jac_det[0])

# %%
jac_det
# Out:
# <tf.Tensor: shape=(1, 512, 512), dtype=float32, numpy=
# array([[[0.99511826, 0.9950336 , 0.9949493 , ..., 0.99812955,
#          0.9981749 , 0.99821866],
#         [0.99503577, 0.9949496 , 0.9948635 , ..., 0.9980926 ,
#          0.99813914, 0.9981839 ],
#         [0.99495274, 0.9948648 , 0.9947771 , ..., 0.9980555 ,
#          0.9981028 , 0.99814856],
#         ...,
#         [0.99918294, 0.9991645 , 0.9991459 , ..., 0.998795  ,
#          0.9988193 , 0.99884284],
#         [0.99920803, 0.99919045, 0.99917245, ..., 0.99882203,
#          0.9988455 , 0.99886864],
#         [0.9992323 , 0.9992152 , 0.99919784, ..., 0.99884844,
#          0.99887156, 0.9988937 ]]], dtype=float32)>

# %%
plt.imshow(im[0, ..., 0])

# %%
jac.shape
# Out:
# TensorShape([1, 512, 512, 2, 2])
